# %%
import sys
from pathlib import Path
import os

# poetry_env = r"C:/Users/LEEYS/AppData/Local/pypoetry/Cache/virtualenvs/src-DdrCI_lD-py3.11/Lib/site-packages"
# if poetry_env not in sys.path:
#     sys.path.insert(0, poetry_env)
    
# 프로젝트 루트로 작업 디렉토리 변경
notebook_dir = Path.cwd()
project_root = notebook_dir.parent

os.chdir(project_root)
sys.path.insert(0, str(project_root / "src"))

# %%
from yamyam_lab.data.config import DataConfig
from yamyam_lab.data.mp_rank import MostPopularRankDataLoader

# Setup config (기본값 사용 가능)
data_config = DataConfig()

print("Current directory:", os.getcwd())
print("Project root:", project_root)
print("=" * 80)
# Out:
# Current directory: c:\Users\LEEYS\Desktop\쩝쩝 Project\yamyam-lab
# Project root: c:\Users\LEEYS\Desktop\쩝쩝 Project\yamyam-lab
# ================================================================================

# %%
"""Test MostPopularRankDataLoader with various configurations."""

# Setup config (similar to most_popular.py)
data_config = DataConfig()

print("Project root:", project_root)
print("Python path:", sys.path[:3])
# Out:
# Project root: c:\Users\LEEYS\Desktop\쩝쩝 Project\yamyam-lab
# Python path: ['c:\\Users\\LEEYS\\Desktop\\쩝쩝 Project\\yamyam-lab\\src', 'c:\\Users\\LEEYS\\Desktop\\쩝쩝 Project\\yamyam-lab\\src', 'C:/Users/LEEYS/AppData/Local/pypoetry/Cache/virtualenvs/src-DdrCI_lD-py3.11/Lib/site-packages']

# %%
# Test 1: Rank by rating for Korean BBQ (최근 6개월, with reference_date)
print("\n[Test 1] Rating-based ranking for Korean BBQ (6M, reference_date=2024-11-01)")
print("-" * 80)
try:
    loader = MostPopularRankDataLoader(
        data_config=data_config,
        diner_category_large="한식",
        diner_category_middle="감자탕",
        rank_method="rating",
        period="6M",
        reference_date="2024-11-01",
        topk=10
    )
    top_diners = loader.load_topk_diners_rank()
    print(f"✓ Success: Found {len(top_diners)} diners")
    print(f"  Top 10 diner_idx: {top_diners}")
except Exception as e:
    print(f"✗ Failed: {e}")
    import traceback
    traceback.print_exc()
# Out:
# [Test 1] Rating-based ranking for Korean BBQ (6M, reference_date=2024-11-01)
# --------------------------------------------------------------------------------
# 기존 data가 존재합니다. 파일 경로를 반환합니다.
# Using reference date: 2024-11-01
# Filtering reviews from 2024-05-05 to 2024-11-01
# ✓ Success: Found 10 diners
#   Top 10 diner_idx: [57377692, 209060102, 519170689, 453427851, 773870943, 1090087264, 1253740453, 857352443, 1775283288, 486497898]

# %%
# Test 2: Rank by distance (all 기간, no reference_date)
print("\n[Test 2] Distance-based ranking for Japanese restaurants (all, auto reference)")
print("-" * 80)
try:
    loader = MostPopularRankDataLoader(
        data_config=data_config,
        diner_category_large="일식",
        rank_method="distance",
        lat=37.5665,  # Seoul coordinates
        lon=126.9780,
        period="all",
        topk=5
    )
    top_diners = loader.load_topk_diners_rank()
    print(f"✓ Success: Found {len(top_diners)} diners")
    print(f"  Top 5 diner_idx: {top_diners}")
except Exception as e:
    print(f"✗ Failed: {e}")
    import traceback
    traceback.print_exc()
# Out:
# [Test 2] Distance-based ranking for Japanese restaurants (all, auto reference)
# --------------------------------------------------------------------------------
# 기존 data가 존재합니다. 파일 경로를 반환합니다.
# ✓ Success: Found 5 diners
#   Top 5 diner_idx: [575856123, 1761696324, 24244754, 1581311090, 1948472361]

# %%
# Test 3: Rank by review count (최근 3개월, with reference_date)
print("\n[Test 3] Review count-based ranking (3M, reference_date=2024-10-15)")
print("-" * 80)
try:
    loader = MostPopularRankDataLoader(
        data_config=data_config,
        rank_method="review_count",
        period="3M",
        reference_date="2024-10-15",
        topk=20
    )
    top_diners = loader.load_topk_diners_rank()
    print(f"✓ Success: Found {len(top_diners)} diners")
    print(f"  Top 20 diner_idx: {top_diners[:10]}... (showing first 10)")
except Exception as e:
    print(f"✗ Failed: {e}")
    import traceback
    traceback.print_exc()
# Out:
# [Test 3] Review count-based ranking (3M, reference_date=2024-10-15)
# --------------------------------------------------------------------------------
# 기존 data가 존재합니다. 파일 경로를 반환합니다.
# Using reference date: 2024-10-15
# Filtering reviews from 2024-07-17 to 2024-10-15
# ✓ Success: Found 20 diners
#   Top 20 diner_idx: [1567102742, 1465970259, 20557155, 959529341, 254918904, 1287091788, 1497730059, 1580890176, 47908415, 856347657]... (showing first 10)

# %%
# Test 4: Rank by rating for Chinese food (최근 1개월)
print("\n[Test 4] Rating-based ranking for Chinese food (1M, reference_date=2024-11-02)")
print("-" * 80)
try:
    loader = MostPopularRankDataLoader(
        data_config=data_config,
        diner_category_large="중식",
        rank_method="rating",
        period="1M",
        reference_date="2024-11-02",
        topk=15
    )
    top_diners = loader.load_topk_diners_rank()
    print(f"✓ Success: Found {len(top_diners)} diners")
    print(f"  Top 15 diner_idx: {top_diners}")
except Exception as e:
    print(f"✗ Failed: {e}")
    import traceback
    traceback.print_exc()

# Test 5: Rank by yamyam_popularity (should return empty list)
print("\n[Test 5] Yamyam popularity-based ranking (not implemented)")
print("-" * 80)
try:
    loader = MostPopularRankDataLoader(
        data_config=data_config,
        rank_method="yamyam_popularity",
        period="all",
        topk=10
    )
    top_diners = loader.load_topk_diners_rank()
    print(f"✓ Success: Returns empty list as expected (length: {len(top_diners)})")
except Exception as e:
    print(f"✗ Failed: {e}")
    import traceback
    traceback.print_exc()
# Out:
# [Test 4] Rating-based ranking for Chinese food (1M, reference_date=2024-11-02)
# --------------------------------------------------------------------------------
# 기존 data가 존재합니다. 파일 경로를 반환합니다.
# Using reference date: 2024-11-02
# Filtering reviews from 2024-10-03 to 2024-11-02
# ✓ Success: Found 15 diners
#   Top 15 diner_idx: [685865166, 880550745, 1955589691, 1550750281, 1295341342, 1357798460, 269083910, 1454411027, 1743190128, 20557327, 1057558855, 173172882, 947723112, 2090639308, 946681070]
#
# [Test 5] Yamyam popularity-based ranking (not implemented)
# --------------------------------------------------------------------------------
# 기존 data가 존재합니다. 파일 경로를 반환합니다.
# yamyam_popularity is not implemented yet. Returning empty list.
# ✓ Success: Returns empty list as expected (length: 0)

# %%
# Test 6: Test with no category filter (all), auto reference date
print("\n[Test 6] No category filter, rating-based (all, auto reference)")
print("-" * 80)
try:
    loader = MostPopularRankDataLoader(
        data_config=data_config,
        rank_method="rating",
        period="all",
        topk=30
    )
    top_diners = loader.load_topk_diners_rank()
    print(f"✓ Success: Found {len(top_diners)} diners")
    print(f"  Top 30 diner_idx: {top_diners[:10]}... (showing first 10)")
except Exception as e:
    print(f"✗ Failed: {e}")
    import traceback
    traceback.print_exc()
# Out:
# [Test 6] No category filter, rating-based (all, auto reference)
# --------------------------------------------------------------------------------
# 기존 data가 존재합니다. 파일 경로를 반환합니다.
# ✓ Success: Found 30 diners
#   Top 30 diner_idx: [26355246, 22109540, 1565842997, 1269485553, 1202493608, 1968862923, 2100440744, 696162313, 1329805738, 1770835120]... (showing first 10)

# %%
# Test 7: Error handling - distance without lat/lon
print("\n[Test 7] Error handling: distance method without coordinates")
print("-" * 80)
try:
    loader = MostPopularRankDataLoader(
        data_config=data_config,
        rank_method="distance",
        period="all",
        topk=10
    )
    print("✗ Failed: Should have raised ValueError")
except ValueError as e:
    print(f"✓ Success: Properly raised error - {e}")
except Exception as e:
    print(f"✗ Failed with unexpected error: {e}")
    import traceback
    traceback.print_exc()
# Out:
# [Test 7] Error handling: distance method without coordinates
# --------------------------------------------------------------------------------
# 기존 data가 존재합니다. 파일 경로를 반환합니다.
# ✓ Success: Properly raised error - lat and lon must be provided when rank_method is 'distance'
